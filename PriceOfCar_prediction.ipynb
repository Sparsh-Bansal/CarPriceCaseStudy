# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
master= pd.read_csv('CarPrice_Assignment.csv')
master.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase   ...     enginesize  \
# 0  convertible        rwd          front       88.6   ...            130
# 1  convertible        rwd          front       88.6   ...            130
# 2    hatchback        rwd          front       94.5   ...            152
# 3        sedan        fwd          front       99.8   ...            109
# 4        sedan        4wd          front       99.4   ...            136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
pd.set_option('display.max_columns',500)
master.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# car_ID              205 non-null int64
# symboling           205 non-null int64
# CarName             205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# horsepower          205 non-null int64
# peakrpm             205 non-null int64
# citympg             205 non-null int64
# highwaympg          205 non-null int64
# price               205 non-null float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.7+ KB

# %%
master.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# citympg           205.0     25.219512     6.542142    13.00    19.00
# highwaympg        205.0     30.751220     6.886443    16.00    25.00
# price             205.0  13276.710571  7988.852332  5118.00  7788.00
#
#                        50%       75%       max
# car_ID              103.00    154.00    205.00
# symboling             1.00      2.00      3.00
# wheelbase            97.00    102.40    120.90
# carlength           173.20    183.10    208.10
# carwidth             65.50     66.90     72.30
# carheight            54.10     55.50     59.80
# curbweight         2414.00   2935.00   4066.00
# enginesize          120.00    141.00    326.00
# boreratio             3.31      3.58      3.94
# stroke                3.29      3.41      4.17
# compressionratio      9.00      9.40     23.00
# horsepower           95.00    116.00    288.00
# peakrpm            5200.00   5500.00   6600.00
# citympg              24.00     30.00     49.00
# highwaympg           30.00     34.00     54.00
# price             10295.00  16503.00  45400.00

# %%
master.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# Get the percentage of null values for each columns
na_percent = round(master.isnull().sum() / len(master.index) * 100, 2)
if any(na_percent[na_percent > 0]):
    print("\nColumns which have null values and there percentage is,\n", na_percent[na_percent > 0])
else:
    print("\nNone of the Columns have null values.\n", na_percent[na_percent > 0])
# Out:
# None of the Columns have null values.
#  Series([], dtype: float64)

# %%
master.head(n=10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
# 5        sedan        fwd          front       99.8      177.3      66.3
# 6        sedan        fwd          front      105.8      192.7      71.4
# 7        wagon        fwd          front      105.8      192.7      71.4
# 8        sedan        fwd          front      105.8      192.7      71.4
# 9    hatchback        4wd          front       99.5      178.2      67.9
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
# 5       53.1        2507        ohc           five         136       mpfi
# 6       55.7        2844        ohc           five         136       mpfi
# 7       55.7        2954        ohc           five         136       mpfi
# 8       55.9        3086        ohc           five         131       mpfi
# 9       52.0        3053        ohc           five         131       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
# 5       3.19    3.40               8.5         110     5500       19
# 6       3.19    3.40               8.5         110     5500       19
# 7       3.19    3.40               8.5         110     5500       19
# 8       3.13    3.40               8.3         140     5500       17
# 9       3.13    3.40               7.0         160     5500       16
#
#    highwaympg      price
# 0          27  13495.000
# 1          27  16500.000
# 2          26  16500.000
# 3          30  13950.000
# 4          22  17450.000
# 5          25  15250.000
# 6          25  17710.000
# 7          25  18920.000
# 8          20  23875.000
# 9          22  17859.167

# %%
master['price']=round(master['price'],2)

# %%
master['price'].head(n=50)
# Out:
# 0     13495.00
# 1     16500.00
# 2     16500.00
# 3     13950.00
# 4     17450.00
# 5     15250.00
# 6     17710.00
# 7     18920.00
# 8     23875.00
# 9     17859.17
# 10    16430.00
# 11    16925.00
# 12    20970.00
# 13    21105.00
# 14    24565.00
# 15    30760.00
# 16    41315.00
# 17    36880.00
# 18     5151.00
# 19     6295.00
# 20     6575.00
# 21     5572.00
# 22     6377.00
# 23     7957.00
# 24     6229.00
# 25     6692.00
# 26     7609.00
# 27     8558.00
# 28     8921.00
# 29    12964.00
# 30     6479.00
# 31     6855.00
# 32     5399.00
# 33     6529.00
# 34     7129.00
# 35     7295.00
# 36     7295.00
# 37     7895.00
# 38     9095.00
# 39     8845.00
# 40    10295.00
# 41    12945.00
# 42    10345.00
# 43     6785.00
# 44     8916.50
# 45     8916.50
# 46    11048.00
# 47    32250.00
# 48    35550.00
# 49    36000.00
# Name: price, dtype: float64

# %%
master[['CompanyName','Model']]=master['CarName'].str.split(' ', n=1,expand=True)
master.drop(['CarName','Model','car_ID'],1,inplace=True)
master.head()
# Categorial Variable
  # symboling
  # fueltype
  # aspiration
  # doornumber
  # carbody
  # drivewheel
  # enginelocation
  # enginetype
  # cylindernumber
  # fuelsystem
  # CompanyName
# UnCategorial Value
  # wheelbase
  # carlength
  # carwidth
  # curbweight
  # UnCategorial Value
  # enginesize
  # boreratio
  # stroke
  # compressionratio
  # horsepower
  # peakrpm
  # citympg
  # highwaympg
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
# 1          front       88.6      168.8      64.1       48.8        2548
# 2          front       94.5      171.2      65.5       52.4        2823
# 3          front       99.8      176.6      66.2       54.3        2337
# 4          front       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0       dohc           four         130       mpfi       3.47    2.68
# 1       dohc           four         130       mpfi       3.47    2.68
# 2       ohcv            six         152       mpfi       2.68    3.47
# 3        ohc           four         109       mpfi       3.19    3.40
# 4        ohc           five         136       mpfi       3.19    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# 0               9.0         111     5000       21          27  13495.0
# 1               9.0         111     5000       21          27  16500.0
# 2               9.0         154     5000       19          26  16500.0
# 3              10.0         102     5500       24          30  13950.0
# 4               8.0         115     5500       18          22  17450.0
#
#    CompanyName
# 0  alfa-romero
# 1  alfa-romero
# 2  alfa-romero
# 3         audi
# 4         audi

# %%
master.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
#case mismatch for 'Nissan', 'nissan'
#'alfa-romeo' is misspelled as 'alfa-romero'
#'mazda' is misspelled as 'maxda'
#'porsche' is misspelled as 'porcshce'
#'toyota' is misspelled as 'toyouta'

#'vokswagen' and 'vw' instead of 'volkswagen' 
# Fixing case mismatch error of 'Nissan', 'nissan'
master['CompanyName'] = master['CompanyName'].str.upper()

# Fixing spelling error- 'alfa-romeo' is misspelled as 'alfa-romero'
master['CompanyName'] = master['CompanyName'].str.replace("ALFA-ROMERO", "ALFA-ROMEO")

# Fixing the spelling mistake of 'maxda' by replacing with correct spelling 'mazda'
master['CompanyName'] = master['CompanyName'].str.replace("MAXDA", "MAZDA")

# Fixing the spelling mistake of 'porcshce' by replacing with correct spelling 'porsche'
master['CompanyName'] = master['CompanyName'].str.replace("PORCSHCE", "PORSCHE")

# Fixing the spelling mistake of 'toyouta' by replacing with correct spelling 'toyota'
master['CompanyName'] = master['CompanyName'].str.replace("TOYOUTA", "TOYOTA")

# Replacing 'vokswagen' and 'vw' with correct spelling 'volkswagen'¶
master['CompanyName'] = master['CompanyName'].str.replace("VOKSWAGEN", "VOLKSWAGEN")
master['CompanyName'] = master['CompanyName'].str.replace("VW", "VOLKSWAGEN")

master.CompanyName.unique()
# Out:
# array(['ALFA-ROMEO', 'AUDI', 'BMW', 'CHEVROLET', 'DODGE', 'HONDA',
#        'ISUZU', 'JAGUAR', 'MAZDA', 'BUICK', 'MERCURY', 'MITSUBISHI',
#        'NISSAN', 'PEUGEOT', 'PLYMOUTH', 'PORSCHE', 'RENAULT', 'SAAB',
#        'SUBARU', 'TOYOTA', 'VOLKSWAGEN', 'VOLVO'], dtype=object)

# %%
master.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
# 1          front       88.6      168.8      64.1       48.8        2548
# 2          front       94.5      171.2      65.5       52.4        2823
# 3          front       99.8      176.6      66.2       54.3        2337
# 4          front       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0       dohc           four         130       mpfi       3.47    2.68
# 1       dohc           four         130       mpfi       3.47    2.68
# 2       ohcv            six         152       mpfi       2.68    3.47
# 3        ohc           four         109       mpfi       3.19    3.40
# 4        ohc           five         136       mpfi       3.19    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# 0               9.0         111     5000       21          27  13495.0
# 1               9.0         111     5000       21          27  16500.0
# 2               9.0         154     5000       19          26  16500.0
# 3              10.0         102     5500       24          30  13950.0
# 4               8.0         115     5500       18          22  17450.0
#
#   CompanyName
# 0  ALFA-ROMEO
# 1  ALFA-ROMEO
# 2  ALFA-ROMEO
# 3        AUDI
# 4        AUDI

# %%
master.describe(include='all').T
# Out:
#                  count unique     top freq      mean       std    min    25%  \
# symboling          205    NaN     NaN  NaN  0.834146   1.24531     -2      0
# fueltype           205      2     gas  185       NaN       NaN    NaN    NaN
# aspiration         205      2     std  168       NaN       NaN    NaN    NaN
# doornumber         205      2    four  115       NaN       NaN    NaN    NaN
# carbody            205      5   sedan   96       NaN       NaN    NaN    NaN
# drivewheel         205      3     fwd  120       NaN       NaN    NaN    NaN
# enginelocation     205      2   front  202       NaN       NaN    NaN    NaN
# wheelbase          205    NaN     NaN  NaN   98.7566   6.02178   86.6   94.5
# carlength          205    NaN     NaN  NaN   174.049   12.3373  141.1  166.3
# carwidth           205    NaN     NaN  NaN   65.9078    2.1452   60.3   64.1
# carheight          205    NaN     NaN  NaN   53.7249   2.44352   47.8     52
# curbweight         205    NaN     NaN  NaN   2555.57    520.68   1488   2145
# enginetype         205      7     ohc  148       NaN       NaN    NaN    NaN
# cylindernumber     205      7    four  159       NaN       NaN    NaN    NaN
# enginesize         205    NaN     NaN  NaN   126.907   41.6427     61     97
# fuelsystem         205      8    mpfi   94       NaN       NaN    NaN    NaN
# boreratio          205    NaN     NaN  NaN   3.32976  0.270844   2.54   3.15
# stroke             205    NaN     NaN  NaN   3.25541  0.313597   2.07   3.11
# compressionratio   205    NaN     NaN  NaN   10.1425   3.97204      7    8.6
# horsepower         205    NaN     NaN  NaN   104.117   39.5442     48     70
# peakrpm            205    NaN     NaN  NaN   5125.12   476.986   4150   4800
# citympg            205    NaN     NaN  NaN   25.2195   6.54214     13     19
# highwaympg         205    NaN     NaN  NaN   30.7512   6.88644     16     25
# price              205    NaN     NaN  NaN   13276.7   7988.85   5118   7788
# CompanyName        205     22  TOYOTA   32       NaN       NaN    NaN    NaN
#
#                     50%    75%    max
# symboling             1      2      3
# fueltype            NaN    NaN    NaN
# aspiration          NaN    NaN    NaN
# doornumber          NaN    NaN    NaN
# carbody             NaN    NaN    NaN
# drivewheel          NaN    NaN    NaN
# enginelocation      NaN    NaN    NaN
# wheelbase            97  102.4  120.9
# carlength         173.2  183.1  208.1
# carwidth           65.5   66.9   72.3
# carheight          54.1   55.5   59.8
# curbweight         2414   2935   4066
# enginetype          NaN    NaN    NaN
# cylindernumber      NaN    NaN    NaN
# enginesize          120    141    326
# fuelsystem          NaN    NaN    NaN
# boreratio          3.31   3.58   3.94
# stroke             3.29   3.41   4.17
# compressionratio      9    9.4     23
# horsepower           95    116    288
# peakrpm            5200   5500   6600
# citympg              24     30     49
# highwaympg           30     34     54
# price             10295  16503  45400
# CompanyName         NaN    NaN    NaN

# %%
def draw_bar_chart(col_name,fig_width,fig_height,xlabel='',ylabel='',title='',xLblRotation=0):
    df = master.groupby(master[col_name]).size().reset_index(name='Frequency')
    plt.figure(figsize=(fig_width,fig_height))
    sns.barplot(x=col_name,y='Frequency',data=df)
    plt.title(title,fontsize=50)
    plt.xticks(fontsize=30,rotation=xLblRotation)
    plt.yticks(fontsize=30)
    plt.xlabel(xlabel,fontsize=30)
    plt.ylabel(ylabel,fontsize=30)
    print(df)
    
#    plt.legend()

# %%
def dummy_variable(data,variable,column_to_drop,Prefix=''):
    dummy=pd.get_dummies(data[variable],prefix=Prefix)
    data=pd.concat([data,dummy],axis=1)
    data=data.drop([variable,column_to_drop],axis=1)
    return data

# %%
draw_bar_chart('symboling',20,10,'SYMBOLING','FREQUENCY','Symboling count')
# Out:
#    symboling  Frequency
# 0         -2          3
# 1         -1         22
# 2          0         67
# 3          1         54
# 4          2         32
# 5          3         27

# %%
master=dummy_variable(master,'symboling','Symboling_-2','Symboling')
master.head(1)
# Out:
#   fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0      gas        std        two  convertible        rwd          front
#
#    wheelbase  carlength  carwidth  carheight  curbweight enginetype  \
# 0       88.6      168.8      64.1       48.8        2548       dohc
#
#   cylindernumber  enginesize fuelsystem  boreratio  stroke  compressionratio  \
# 0           four         130       mpfi       3.47    2.68               9.0
#
#    horsepower  peakrpm  citympg  highwaympg    price CompanyName  \
# 0         111     5000       21          27  13495.0  ALFA-ROMEO
#
#    Symboling_-1  Symboling_0  Symboling_1  Symboling_2  Symboling_3
# 0             0            0            0            0            1

# %%
draw_bar_chart('fueltype',5,10,'FUELTYPE','FREQUENCY','FUELTYPE COUNT')
# Out:
#   fueltype  Frequency
# 0   diesel         20
# 1      gas        185

# %%
master=dummy_variable(master,'fueltype','FuelType_diesel','FuelType')
master.head(1)
# Out:
#   aspiration doornumber      carbody drivewheel enginelocation  wheelbase  \
# 0        std        two  convertible        rwd          front       88.6
#
#    carlength  carwidth  carheight  curbweight enginetype cylindernumber  \
# 0      168.8      64.1       48.8        2548       dohc           four
#
#    enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# 0         130       mpfi       3.47    2.68               9.0         111
#
#    peakrpm  citympg  highwaympg    price CompanyName  Symboling_-1  \
# 0     5000       21          27  13495.0  ALFA-ROMEO             0
#
#    Symboling_0  Symboling_1  Symboling_2  Symboling_3  FuelType_gas
# 0            0            0            0            1             1

# %%
draw_bar_chart('aspiration',5,10,'ASPIRATION','FREQUENCY','ASPIRATION COUNT')
# Out:
#   aspiration  Frequency
# 0        std        168
# 1      turbo         37

# %%
master=dummy_variable(master,'aspiration','Aspiration_turbo','Aspiration')
master.head(1)
# Out:
#   doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# 0        two  convertible        rwd          front       88.6      168.8
#
#    carwidth  carheight  curbweight enginetype cylindernumber  enginesize  \
# 0      64.1       48.8        2548       dohc           four         130
#
#   fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0       mpfi       3.47    2.68               9.0         111     5000
#
#    citympg  highwaympg    price CompanyName  Symboling_-1  Symboling_0  \
# 0       21          27  13495.0  ALFA-ROMEO             0            0
#
#    Symboling_1  Symboling_2  Symboling_3  FuelType_gas  Aspiration_std
# 0            0            0            1             1               1

# %%
draw_bar_chart('doornumber',5,10,'DOORNUMBER','FREQUENCY','Doornumber Count')
# Out:
#   doornumber  Frequency
# 0       four        115
# 1        two         90

# %%
master=dummy_variable(master,'doornumber','DoorNumber_two','DoorNumber')
master.head(1)
# Out:
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
#
#    highwaympg    price CompanyName  Symboling_-1  Symboling_0  Symboling_1  \
# 0          27  13495.0  ALFA-ROMEO             0            0            0
#
#    Symboling_2  Symboling_3  FuelType_gas  Aspiration_std  DoorNumber_four
# 0            0            1             1               1                0

# %%
draw_bar_chart('carbody',20,10,'CARBODY','FREQUENCY','Carbody Count')
# Out:
#        carbody  Frequency
# 0  convertible          6
# 1      hardtop          8
# 2    hatchback         70
# 3        sedan         96
# 4        wagon         25

# %%
master=dummy_variable(master,'carbody','Carbody_convertible','Carbody')
master.head(1)
# Out:
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
#
#    curbweight enginetype cylindernumber  enginesize fuelsystem  boreratio  \
# 0        2548       dohc           four         130       mpfi       3.47
#
#    stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 0    2.68               9.0         111     5000       21          27
#
#      price CompanyName  Symboling_-1  Symboling_0  Symboling_1  Symboling_2  \
# 0  13495.0  ALFA-ROMEO             0            0            0            0
#
#    Symboling_3  FuelType_gas  Aspiration_std  DoorNumber_four  \
# 0            1             1               1                0
#
#    Carbody_hardtop  Carbody_hatchback  Carbody_sedan  Carbody_wagon
# 0                0                  0              0              0

# %%
draw_bar_chart('drivewheel',7,10,'DRIVEWHEEL','FREQUENCY','DRIVEWHEEL COUNT')
# Out:
#   drivewheel  Frequency
# 0        4wd          9
# 1        fwd        120
# 2        rwd         76

# %%
master=dummy_variable(master,'drivewheel','DriveWheel_4wd','DriveWheel')
master.head(1)
# Out:
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0       dohc           four         130       mpfi       3.47    2.68
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# 0               9.0         111     5000       21          27  13495.0
#
#   CompanyName  Symboling_-1  Symboling_0  Symboling_1  Symboling_2  \
# 0  ALFA-ROMEO             0            0            0            0
#
#    Symboling_3  FuelType_gas  Aspiration_std  DoorNumber_four  \
# 0            1             1               1                0
#
#    Carbody_hardtop  Carbody_hatchback  Carbody_sedan  Carbody_wagon  \
# 0                0                  0              0              0
#
#    DriveWheel_fwd  DriveWheel_rwd
# 0               0               1

# %%
draw_bar_chart('enginelocation',5,10,'ENGINELOCATION','FREQUENCY','ENGINE LOCATION COUNT')
# Out:
#   enginelocation  Frequency
# 0          front        202
# 1           rear          3

# %%
master=dummy_variable(master,'enginelocation','EngineLocation_rear','EngineLocation')
master.head(1)
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight enginetype  \
# 0       88.6      168.8      64.1       48.8        2548       dohc
#
#   cylindernumber  enginesize fuelsystem  boreratio  stroke  compressionratio  \
# 0           four         130       mpfi       3.47    2.68               9.0
#
#    horsepower  peakrpm  citympg  highwaympg    price CompanyName  \
# 0         111     5000       21          27  13495.0  ALFA-ROMEO
#
#    Symboling_-1  Symboling_0  Symboling_1  Symboling_2  Symboling_3  \
# 0             0            0            0            0            1
#
#    FuelType_gas  Aspiration_std  DoorNumber_four  Carbody_hardtop  \
# 0             1               1                0                0
#
#    Carbody_hatchback  Carbody_sedan  Carbody_wagon  DriveWheel_fwd  \
# 0                  0              0              0               0
#
#    DriveWheel_rwd  EngineLocation_front
# 0               1                     1

# %%
draw_bar_chart('enginetype',20,10,'ENGINETYPE','FREQUENCY','ENGINETYPE COUNT')
# Out:
#   enginetype  Frequency
# 0       dohc         12
# 1      dohcv          1
# 2          l         12
# 3        ohc        148
# 4       ohcf         15
# 5       ohcv         13
# 6      rotor          4

# %%
master=dummy_variable(master,'enginetype','EngineType_dohcv','EngineType')
master.head(1)
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight cylindernumber  \
# 0       88.6      168.8      64.1       48.8        2548           four
#
#    enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# 0         130       mpfi       3.47    2.68               9.0         111
#
#    peakrpm  citympg  highwaympg    price CompanyName  Symboling_-1  \
# 0     5000       21          27  13495.0  ALFA-ROMEO             0
#
#    Symboling_0  Symboling_1  Symboling_2  Symboling_3  FuelType_gas  \
# 0            0            0            0            1             1
#
#    Aspiration_std  DoorNumber_four  Carbody_hardtop  Carbody_hatchback  \
# 0               1                0                0                  0
#
#    Carbody_sedan  Carbody_wagon  DriveWheel_fwd  DriveWheel_rwd  \
# 0              0              0               0               1
#
#    EngineLocation_front  EngineType_dohc  EngineType_l  EngineType_ohc  \
# 0                     1                1             0               0
#
#    EngineType_ohcf  EngineType_ohcv  EngineType_rotor
# 0                0                0                 0

# %%
draw_bar_chart('cylindernumber',20,10,'CYLINDER NUMBER','FREQUENCY','CYLINDER NUMBER COUNT')
# Out:
#   cylindernumber  Frequency
# 0          eight          5
# 1           five         11
# 2           four        159
# 3            six         24
# 4          three          1
# 5         twelve          1
# 6            two          4

# %%
master=dummy_variable(master,'cylindernumber','CylinderNumber_three','CylinderNumber')
master=master.drop(['CylinderNumber_twelve'],axis=1)
master.head(1)
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0       88.6      168.8      64.1       48.8        2548         130
#
#   fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0       mpfi       3.47    2.68               9.0         111     5000
#
#    citympg  highwaympg    price CompanyName  Symboling_-1  Symboling_0  \
# 0       21          27  13495.0  ALFA-ROMEO             0            0
#
#    Symboling_1  Symboling_2  Symboling_3  FuelType_gas  Aspiration_std  \
# 0            0            0            1             1               1
#
#    DoorNumber_four  Carbody_hardtop  Carbody_hatchback  Carbody_sedan  \
# 0                0                0                  0              0
#
#    Carbody_wagon  DriveWheel_fwd  DriveWheel_rwd  EngineLocation_front  \
# 0              0               0               1                     1
#
#    EngineType_dohc  EngineType_l  EngineType_ohc  EngineType_ohcf  \
# 0                1             0               0                0
#
#    EngineType_ohcv  EngineType_rotor  CylinderNumber_eight  \
# 0                0                 0                     0
#
#    CylinderNumber_five  CylinderNumber_four  CylinderNumber_six  \
# 0                    0                    1                   0
#
#    CylinderNumber_two
# 0                   0

# %%
draw_bar_chart('fuelsystem',20,8,'FUELSYSTEM','FREQUENCY','FUELSYSTEM COUNT')
# Out:
#   fuelsystem  Frequency
# 0       1bbl         11
# 1       2bbl         66
# 2       4bbl          3
# 3        idi         20
# 4        mfi          1
# 5       mpfi         94
# 6       spdi          9
# 7       spfi          1

# %%
master=dummy_variable(master,'fuelsystem','FuelSystem_mfi','FuelSystem')
master=master.drop(['FuelSystem_spfi'],axis=1)
master.head(1)
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0       88.6      168.8      64.1       48.8        2548         130
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
#
#    highwaympg    price CompanyName  Symboling_-1  Symboling_0  Symboling_1  \
# 0          27  13495.0  ALFA-ROMEO             0            0            0
#
#    Symboling_2  Symboling_3  FuelType_gas  Aspiration_std  DoorNumber_four  \
# 0            0            1             1               1                0
#
#    Carbody_hardtop  Carbody_hatchback  Carbody_sedan  Carbody_wagon  \
# 0                0                  0              0              0
#
#    DriveWheel_fwd  DriveWheel_rwd  EngineLocation_front  EngineType_dohc  \
# 0               0               1                     1                1
#
#    EngineType_l  EngineType_ohc  EngineType_ohcf  EngineType_ohcv  \
# 0             0               0                0                0
#
#    EngineType_rotor  CylinderNumber_eight  CylinderNumber_five  \
# 0                 0                     0                    0
#
#    CylinderNumber_four  CylinderNumber_six  CylinderNumber_two  \
# 0                    1                   0                   0
#
#    FuelSystem_1bbl  FuelSystem_2bbl  FuelSystem_4bbl  FuelSystem_idi  \
# 0                0                0                0               0
#
#    FuelSystem_mpfi  FuelSystem_spdi
# 0                1                0

# %%
draw_bar_chart('CompanyName',30,10,'COMPANYNAME','FREQUENCY','COMPANYNAME COUNT',80)
# Out:
#    CompanyName  Frequency
# 0   ALFA-ROMEO          3
# 1         AUDI          7
# 2          BMW          8
# 3        BUICK          8
# 4    CHEVROLET          3
# 5        DODGE          9
# 6        HONDA         13
# 7        ISUZU          4
# 8       JAGUAR          3
# 9        MAZDA         17
# 10     MERCURY          1
# 11  MITSUBISHI         13
# 12      NISSAN         18
# 13     PEUGEOT         11
# 14    PLYMOUTH          7
# 15     PORSCHE          5
# 16     RENAULT          2
# 17        SAAB          6
# 18      SUBARU         12
# 19      TOYOTA         32
# 20  VOLKSWAGEN         12
# 21       VOLVO         11

# %%
master=dummy_variable(master,'CompanyName','CompanyName_MERCURY','CompanyName')
master.head(1)
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0       88.6      168.8      64.1       48.8        2548         130
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
#
#    highwaympg    price  Symboling_-1  Symboling_0  Symboling_1  Symboling_2  \
# 0          27  13495.0             0            0            0            0
#
#    Symboling_3  FuelType_gas  Aspiration_std  DoorNumber_four  \
# 0            1             1               1                0
#
#    Carbody_hardtop  Carbody_hatchback  Carbody_sedan  Carbody_wagon  \
# 0                0                  0              0              0
#
#    DriveWheel_fwd  DriveWheel_rwd  EngineLocation_front  EngineType_dohc  \
# 0               0               1                     1                1
#
#    EngineType_l  EngineType_ohc  EngineType_ohcf  EngineType_ohcv  \
# 0             0               0                0                0
#
#    EngineType_rotor  CylinderNumber_eight  CylinderNumber_five  \
# 0                 0                     0                    0
#
#    CylinderNumber_four  CylinderNumber_six  CylinderNumber_two  \
# 0                    1                   0                   0
#
#    FuelSystem_1bbl  FuelSystem_2bbl  FuelSystem_4bbl  FuelSystem_idi  \
# 0                0                0                0               0
#
#    FuelSystem_mpfi  FuelSystem_spdi  CompanyName_ALFA-ROMEO  CompanyName_AUDI  \
# 0                1                0                       1                 0
#
#    CompanyName_BMW  CompanyName_BUICK  CompanyName_CHEVROLET  \
# 0                0                  0                      0
#
#    CompanyName_DODGE  CompanyName_HONDA  CompanyName_ISUZU  \
# 0                  0                  0                  0
#
#    CompanyName_JAGUAR  CompanyName_MAZDA  CompanyName_MITSUBISHI  \
# 0                   0                  0                       0
#
#    CompanyName_NISSAN  CompanyName_PEUGEOT  CompanyName_PLYMOUTH  \
# 0                   0                    0                     0
#
#    CompanyName_PORSCHE  CompanyName_RENAULT  CompanyName_SAAB  \
# 0                    0                    0                 0
#
#    CompanyName_SUBARU  CompanyName_TOYOTA  CompanyName_VOLKSWAGEN  \
# 0                   0                   0                       0
#
#    CompanyName_VOLVO
# 0                  0

# %%
def draw_scatter_plot(data,X,Y,title):
    plt.figure(figsize=(20,10))
    plt.scatter(x=X,y=Y,s=np.pi*25,c=np.random.choice(['blue','green','red']),marker='o',alpha=0.75,data=data)
    plt.xlabel(X,fontsize=30)
    plt.ylabel('Price',fontsize=30)
    plt.title(title,fontsize=40)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.legend(fontsize=20)
    plt.show()
    #plt.boxplot(x=data[X],y=data[Y],showfliers=True,fliersize=8,color='blue')

# %%
def draw_boxplot(data,X):
    plt.figure(figsize=(15,5))
    sns.boxplot(x=data[X],color='blue',fliersize=10)
    plt.title('BoxPlot',fontsize=40)
    plt.xlabel(X,fontsize=30)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.legend(fontsize=20)
    plt.show()
    print(master.shape)

# %%
def remove_outliers(data,X):
    data= data[data[X] >= data[X].quantile(0.01)]
    data=data[data[X] <= data[X].quantile(0.99)]
    print(data.shape)
    return data

# %%
 # wheelbase
  # carlength
  # carwidth
  # carheight
  # curbweight
  # enginesize
  # boreratio
  # stroke
  # compressionratio
  # horsepower
  # peakrpm
  # citympg
  # highwaympg  
draw_scatter_plot(master,'carlength','price','Price and CarLength')

# %%
draw_boxplot(master,'carlength')
# Out:
# No handles with labels found to put in legend.
# (205, 67)

# %%
master=remove_outliers(master,'carlength')
# Out:
# (199, 67)

# %%
draw_scatter_plot(master,'carwidth','price','Price and Carwidth')

# %%
draw_boxplot(master,'carwidth')
# Out:
# No handles with labels found to put in legend.
# (199, 67)

# %%
master=remove_outliers(master,'carwidth')
# Out:
# (195, 67)

# %%
draw_scatter_plot(master,'carheight','price','Price and CarHeight')

# %%
master=master.drop(['carheight'],axis=1)

# %%
draw_scatter_plot(master,'curbweight','price','Price and CurbWeight')

# %%
draw_boxplot(master,'curbweight')
# Out:
# No handles with labels found to put in legend.
# (195, 66)

# %%
master=remove_outliers(master,'curbweight')
# Out:
# (192, 66)

# %%
draw_scatter_plot(master,'enginesize','price','Price and EngineSize')

# %%
draw_boxplot(master,'enginesize')
# Out:
# No handles with labels found to put in legend.
# (192, 66)

# %%
master=remove_outliers(master,'enginesize')
# Out:
# (190, 66)

# %%
draw_scatter_plot(master,'boreratio','price','Price and BoreRatio')

# %%
draw_boxplot(master,'boreratio')
# Out:
# No handles with labels found to put in legend.
# (190, 66)

# %%
master=master.drop(['boreratio'],axis=1)

# %%
draw_scatter_plot(master,'stroke','price','Price and Stroke')

# %%
master=master.drop(['stroke'],axis=1)

# %%
draw_scatter_plot(master,'compressionratio','price','Price and CompressionRatio')

# %%
master=master.drop(['compressionratio'],axis=1)

# %%
draw_scatter_plot(master,'horsepower','price','Price and HorsePower')

# %%
draw_boxplot(master,'horsepower')
# Out:
# No handles with labels found to put in legend.
# (190, 63)

# %%
master=remove_outliers(master,'horsepower')
# Out:
# (188, 63)

# %%
draw_scatter_plot(master,'peakrpm','price','Price and Peak_RPM')

# %%
master=master.drop(['peakrpm'],1)

# %%
draw_scatter_plot(master,'citympg','price','Price and City_MPG')

# %%
draw_boxplot(master,'citympg')
# Out:
# No handles with labels found to put in legend.
# (188, 62)

# %%
draw_scatter_plot(master,'highwaympg','price','Price and Highway_MPG')

# %%
draw_boxplot(master,'highwaympg')
# Out:
# No handles with labels found to put in legend.
# (188, 62)

# %%
master=remove_outliers(master,'highwaympg')
# Out:
# (185, 62)

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185 entries, 0 to 204
# Data columns (total 62 columns):
# wheelbase                 185 non-null float64
# carlength                 185 non-null float64
# carwidth                  185 non-null float64
# curbweight                185 non-null int64
# enginesize                185 non-null int64
# horsepower                185 non-null int64
# citympg                   185 non-null int64
# highwaympg                185 non-null int64
# price                     185 non-null float64
# Symboling_-1              185 non-null uint8
# Symboling_0               185 non-null uint8
# Symboling_1               185 non-null uint8
# Symboling_2               185 non-null uint8
# Symboling_3               185 non-null uint8
# FuelType_gas              185 non-null uint8
# Aspiration_std            185 non-null uint8
# DoorNumber_four           185 non-null uint8
# Carbody_hardtop           185 non-null uint8
# Carbody_hatchback         185 non-null uint8
# Carbody_sedan             185 non-null uint8
# Carbody_wagon             185 non-null uint8
# DriveWheel_fwd            185 non-null uint8
# DriveWheel_rwd            185 non-null uint8
# EngineLocation_front      185 non-null uint8
# EngineType_dohc           185 non-null uint8
# EngineType_l              185 non-null uint8
# EngineType_ohc            185 non-null uint8
# EngineType_ohcf           185 non-null uint8
# EngineType_ohcv           185 non-null uint8
# EngineType_rotor          185 non-null uint8
# CylinderNumber_eight      185 non-null uint8
# CylinderNumber_five       185 non-null uint8
# CylinderNumber_four       185 non-null uint8
# CylinderNumber_six        185 non-null uint8
# CylinderNumber_two        185 non-null uint8
# FuelSystem_1bbl           185 non-null uint8
# FuelSystem_2bbl           185 non-null uint8
# FuelSystem_4bbl           185 non-null uint8
# FuelSystem_idi            185 non-null uint8
# FuelSystem_mpfi           185 non-null uint8
# FuelSystem_spdi           185 non-null uint8
# CompanyName_ALFA-ROMEO    185 non-null uint8
# CompanyName_AUDI          185 non-null uint8
# CompanyName_BMW           185 non-null uint8
# CompanyName_BUICK         185 non-null uint8
# CompanyName_CHEVROLET     185 non-null uint8
# CompanyName_DODGE         185 non-null uint8
# CompanyName_HONDA         185 non-null uint8
# CompanyName_ISUZU         185 non-null uint8
# CompanyName_JAGUAR        185 non-null uint8
# CompanyName_MAZDA         185 non-null uint8
# CompanyName_MITSUBISHI    185 non-null uint8
# CompanyName_NISSAN        185 non-null uint8
# CompanyName_PEUGEOT       185 non-null uint8
# CompanyName_PLYMOUTH      185 non-null uint8
# CompanyName_PORSCHE       185 non-null uint8
# CompanyName_RENAULT       185 non-null uint8
# CompanyName_SAAB          185 non-null uint8
# CompanyName_SUBARU        185 non-null uint8
# CompanyName_TOYOTA        185 non-null uint8
# CompanyName_VOLKSWAGEN    185 non-null uint8
# CompanyName_VOLVO         185 non-null uint8
# dtypes: float64(4), int64(5), uint8(53)
# memory usage: 24.0 KB

# %%
master=  (master-master.mean())/(master.std())
master.head()
# Out:
#    wheelbase  carlength  carwidth  curbweight  enginesize  horsepower  \
# 0  -1.870019  -0.433616 -0.934661    0.078916    0.279279    0.287706
# 1  -1.870019  -0.433616 -0.934661    0.078916    0.279279    0.287706
# 2  -0.746051  -0.211787 -0.126120    0.701760    1.025122    1.572773
# 3   0.263615   0.287329  0.278151   -0.398975   -0.432662    0.018739
# 4   0.187414   0.287329  0.393657    0.704024    0.482691    0.407247
#
#     citympg  highwaympg     price  Symboling_-1  Symboling_0  Symboling_1  \
# 0 -0.747691   -0.658056  0.193544     -0.347213    -0.690945    -0.598621
# 1 -0.747691   -0.658056  0.678564     -0.347213    -0.690945    -0.598621
# 2 -1.104194   -0.831475  0.678564     -0.347213    -0.690945     1.661477
# 3 -0.212938   -0.137798  0.266983     -0.347213    -0.690945    -0.598621
# 4 -1.282445   -1.525152  0.831899     -0.347213    -0.690945    -0.598621
#
#    Symboling_2  Symboling_3  FuelType_gas  Aspiration_std  DoorNumber_four  \
# 0    -0.412265     2.466238       0.30686        0.481739        -1.142543
# 1    -0.412265     2.466238       0.30686        0.481739        -1.142543
# 2    -0.412265    -0.403284       0.30686        0.481739        -1.142543
# 3     2.412513    -0.403284       0.30686        0.481739         0.870509
# 4     2.412513    -0.403284       0.30686        0.481739         0.870509
#
#    Carbody_hardtop  Carbody_hatchback  Carbody_sedan  Carbody_wagon  \
# 0        -0.197771          -0.733988      -0.899626      -0.394215
# 1        -0.197771          -0.733988      -0.899626      -0.394215
# 2        -0.197771           1.355055      -0.899626      -0.394215
# 3        -0.197771          -0.733988       1.105565      -0.394215
# 4        -0.197771          -0.733988       1.105565      -0.394215
#
#    DriveWheel_fwd  DriveWheel_rwd  EngineLocation_front  EngineType_dohc  \
# 0       -1.221430        1.355055              0.128041         4.171979
# 1       -1.221430        1.355055              0.128041         4.171979
# 2       -1.221430        1.355055              0.128041        -0.238399
# 3        0.814287       -0.733988              0.128041        -0.238399
# 4       -1.221430       -0.733988              0.128041        -0.238399
#
#    EngineType_l  EngineType_ohc  EngineType_ohcf  EngineType_ohcv  \
# 0     -0.250752       -1.684856         -0.29624        -0.212022
# 1     -0.250752       -1.684856         -0.29624        -0.212022
# 2     -0.250752       -1.684856         -0.29624         4.690992
# 3     -0.250752        0.590314         -0.29624        -0.212022
# 4     -0.250752        0.590314         -0.29624        -0.212022
#
#    EngineType_rotor  CylinderNumber_eight  CylinderNumber_five  \
# 0         -0.148257                   NaN            -0.225522
# 1         -0.148257                   NaN            -0.225522
# 2         -0.148257                   NaN            -0.225522
# 3         -0.148257                   NaN            -0.225522
# 4         -0.148257                   NaN             4.410198
#
#    CylinderNumber_four  CylinderNumber_six  CylinderNumber_two  \
# 0             0.473232           -0.356871           -0.148257
# 1             0.473232           -0.356871           -0.148257
# 2            -2.101706            2.786989           -0.148257
# 3             0.473232           -0.356871           -0.148257
# 4            -2.101706           -0.356871           -0.148257
#
#    FuelSystem_1bbl  FuelSystem_2bbl  FuelSystem_4bbl  FuelSystem_idi  \
# 0        -0.197771        -0.725304        -0.128041        -0.30686
# 1        -0.197771        -0.725304        -0.128041        -0.30686
# 2        -0.197771        -0.725304        -0.128041        -0.30686
# 3        -0.197771        -0.725304        -0.128041        -0.30686
# 4        -0.197771        -0.725304        -0.128041        -0.30686
#
#    FuelSystem_mpfi  FuelSystem_spdi  CompanyName_ALFA-ROMEO  CompanyName_AUDI  \
# 0         1.093564        -0.225522                7.767801         -0.182588
# 1         1.093564        -0.225522                7.767801         -0.182588
# 2         1.093564        -0.225522                7.767801         -0.182588
# 3         1.093564        -0.225522               -0.128041          5.447208
# 4         1.093564        -0.225522               -0.128041          5.447208
#
#    CompanyName_BMW  CompanyName_BUICK  CompanyName_CHEVROLET  \
# 0        -0.197771          -0.128041              -0.104259
# 1        -0.197771          -0.128041              -0.104259
# 2        -0.197771          -0.128041              -0.104259
# 3        -0.197771          -0.128041              -0.104259
# 4        -0.197771          -0.128041              -0.104259
#
#    CompanyName_DODGE  CompanyName_HONDA  CompanyName_ISUZU  \
# 0          -0.225522          -0.225522          -0.128041
# 1          -0.225522          -0.225522          -0.128041
# 2          -0.225522          -0.225522          -0.128041
# 3          -0.225522          -0.225522          -0.128041
# 4          -0.225522          -0.225522          -0.128041
#
#    CompanyName_JAGUAR  CompanyName_MAZDA  CompanyName_MITSUBISHI  \
# 0                 NaN          -0.317244               -0.274177
# 1                 NaN          -0.317244               -0.274177
# 2                 NaN          -0.317244               -0.274177
# 3                 NaN          -0.317244               -0.274177
# 4                 NaN          -0.317244               -0.274177
#
#    CompanyName_NISSAN  CompanyName_PEUGEOT  CompanyName_PLYMOUTH  \
# 0           -0.317244            -0.250752             -0.197771
# 1           -0.317244            -0.250752             -0.197771
# 2           -0.317244            -0.250752             -0.197771
# 3           -0.317244            -0.250752             -0.197771
# 4           -0.317244            -0.250752             -0.197771
#
#    CompanyName_PORSCHE  CompanyName_RENAULT  CompanyName_SAAB  \
# 0            -0.148257            -0.104259         -0.182588
# 1            -0.148257            -0.104259         -0.182588
# 2            -0.148257            -0.104259         -0.182588
# 3            -0.148257            -0.104259         -0.182588
# 4            -0.148257            -0.104259         -0.182588
#
#    CompanyName_SUBARU  CompanyName_TOYOTA  CompanyName_VOLKSWAGEN  \
# 0           -0.262658           -0.456092               -0.238399
# 1           -0.262658           -0.456092               -0.238399
# 2           -0.262658           -0.456092               -0.238399
# 3           -0.262658           -0.456092               -0.238399
# 4           -0.262658           -0.456092               -0.238399
#
#    CompanyName_VOLVO
# 0          -0.250752
# 1          -0.250752
# 2          -0.250752
# 3          -0.250752
# 4          -0.250752

# %%
master[['CylinderNumber_eight','CompanyName_JAGUAR']].isnull().sum()
# Out:
# CylinderNumber_eight    185
# CompanyName_JAGUAR      185
# dtype: int64

# %%
master=master.drop(['CylinderNumber_eight','CompanyName_JAGUAR'],axis=1)
master.shape
# Out:
# (185, 60)

# %%
from sklearn.model_selection import train_test_split as tt
X=master.drop(['price'],axis=1)
Y=master['price']
X_train,X_test,Y_train,Y_test= tt(X,Y,train_size=0.7,test_size=0.3,random_state=100)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(X_train,Y_train)
rfe=RFE(lm,25)
rfe.fit(X_train,Y_train)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [ True  True  True  True False  True False False False False False False
#   True  True False False False  True  True  True False  True  True  True
#   True False False  True False False False  True False False  True False
#  False  True False  True  True  True  True False False False False False
#  False False  True False  True False  True False False False False]
# [ 1  1  1  1 17  1 12 13  5  2  4  6  1  1 30  8 22  1  1  1 23  1  1  1
#   1 10 21  1 32 25 24  1 26 19  1 20  7  1 18  1  1  1  1 28 11 16 15 35
#  27 29  1  9  1 34  1 31  3 33 14]

# %%
col=X_train.columns[rfe.support_]
X_train_rfe=X_train[col]
X_test_rfe=X_test[col]
master_new=master[col]
master_new=pd.concat([master_new,master['price']],axis=1)
master_new.head()
# Out:
#    wheelbase  carlength  carwidth  curbweight  horsepower  Symboling_3  \
# 0  -1.870019  -0.433616 -0.934661    0.078916    0.287706     2.466238
# 1  -1.870019  -0.433616 -0.934661    0.078916    0.287706     2.466238
# 2  -0.746051  -0.211787 -0.126120    0.701760    1.572773    -0.403284
# 3   0.263615   0.287329  0.278151   -0.398975    0.018739    -0.403284
# 4   0.187414   0.287329  0.393657    0.704024    0.407247    -0.403284
#
#    FuelType_gas  Carbody_hatchback  Carbody_sedan  Carbody_wagon  \
# 0       0.30686          -0.733988      -0.899626      -0.394215
# 1       0.30686          -0.733988      -0.899626      -0.394215
# 2       0.30686           1.355055      -0.899626      -0.394215
# 3       0.30686          -0.733988       1.105565      -0.394215
# 4       0.30686          -0.733988       1.105565      -0.394215
#
#    DriveWheel_rwd  EngineLocation_front  EngineType_dohc  EngineType_l  \
# 0        1.355055              0.128041         4.171979     -0.250752
# 1        1.355055              0.128041         4.171979     -0.250752
# 2        1.355055              0.128041        -0.238399     -0.250752
# 3       -0.733988              0.128041        -0.238399     -0.250752
# 4       -0.733988              0.128041        -0.238399     -0.250752
#
#    EngineType_ohcv  CylinderNumber_six  FuelSystem_2bbl  FuelSystem_mpfi  \
# 0        -0.212022           -0.356871        -0.725304         1.093564
# 1        -0.212022           -0.356871        -0.725304         1.093564
# 2         4.690992            2.786989        -0.725304         1.093564
# 3        -0.212022           -0.356871        -0.725304         1.093564
# 4        -0.212022           -0.356871        -0.725304         1.093564
#
#    CompanyName_ALFA-ROMEO  CompanyName_AUDI  CompanyName_BMW  \
# 0                7.767801         -0.182588        -0.197771
# 1                7.767801         -0.182588        -0.197771
# 2                7.767801         -0.182588        -0.197771
# 3               -0.128041          5.447208        -0.197771
# 4               -0.128041          5.447208        -0.197771
#
#    CompanyName_BUICK  CompanyName_PEUGEOT  CompanyName_PORSCHE  \
# 0          -0.128041            -0.250752            -0.148257
# 1          -0.128041            -0.250752            -0.148257
# 2          -0.128041            -0.250752            -0.148257
# 3          -0.128041            -0.250752            -0.148257
# 4          -0.128041            -0.250752            -0.148257
#
#    CompanyName_SAAB     price
# 0         -0.182588  0.193544
# 1         -0.182588  0.678564
# 2         -0.182588  0.678564
# 3         -0.182588  0.266983
# 4         -0.182588  0.831899

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
X_train_rfe=sm.add_constant(X_train_rfe)
X_test_rfe = sm.add_constant(X_test_rfe)
# UDF for calculating vif value
def statsmodels_vif_cal(input_data, dependent_col):
    X = input_data.drop([dependent_col], axis=1)
    # For each X, calculate VIF and save in dataframe
    vif = pd.DataFrame(columns = ['Var', 'Vif'])
    vif["Var"] = X.columns
    vif["Vif"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif.sort_values(by = 'Vif', axis=0, ascending=False, inplace=False).round(2)

statsmodels_vif_cal(master_new,'price')
# vif = pd.Series([variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])])
# print(vif)
# Out:
# /home/sparsh/anaconda3/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                        Var        Vif
# 22     CompanyName_PEUGEOT        inf
# 13            EngineType_l        inf
# 3               curbweight  15.550000
# 1                carlength  13.340000
# 2                 carwidth  10.380000
# 0                wheelbase   9.300000
# 4               horsepower   8.690000
# 8            Carbody_sedan   8.340000
# 7        Carbody_hatchback   7.500000
# 11    EngineLocation_front   6.540000
# 15      CylinderNumber_six   5.270000
# 23     CompanyName_PORSCHE   4.900000
# 9            Carbody_wagon   4.820000
# 17         FuelSystem_mpfi   4.500000
# 16         FuelSystem_2bbl   3.870000
# 14         EngineType_ohcv   3.470000
# 6             FuelType_gas   3.180000
# 10          DriveWheel_rwd   3.000000
# 20         CompanyName_BMW   2.310000
# 5              Symboling_3   2.290000
# 12         EngineType_dohc   2.280000
# 21       CompanyName_BUICK   1.990000
# 24        CompanyName_SAAB   1.680000
# 18  CompanyName_ALFA-ROMEO   1.590000
# 19        CompanyName_AUDI   1.460000

# %%
master_new=master_new.drop(['CompanyName_PEUGEOT'],axis=1)

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var    Vif
# 3               curbweight  15.55
# 1                carlength  13.34
# 2                 carwidth  10.38
# 0                wheelbase   9.30
# 4               horsepower   8.69
# 8            Carbody_sedan   8.34
# 7        Carbody_hatchback   7.50
# 11    EngineLocation_front   6.54
# 15      CylinderNumber_six   5.27
# 22     CompanyName_PORSCHE   4.90
# 9            Carbody_wagon   4.82
# 17         FuelSystem_mpfi   4.50
# 16         FuelSystem_2bbl   3.87
# 14         EngineType_ohcv   3.47
# 6             FuelType_gas   3.18
# 10          DriveWheel_rwd   3.00
# 13            EngineType_l   2.38
# 20         CompanyName_BMW   2.31
# 5              Symboling_3   2.29
# 12         EngineType_dohc   2.28
# 21       CompanyName_BUICK   1.99
# 23        CompanyName_SAAB   1.68
# 18  CompanyName_ALFA-ROMEO   1.59
# 19        CompanyName_AUDI   1.46

# %%
# import statsmodels.api as sm
X_train_rfe=X_train_rfe.drop(['CompanyName_PEUGEOT'],axis=1)
X_test_rfe=X_test_rfe.drop(['CompanyName_PEUGEOT'],axis=1)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm2=sm.OLS(Y_train,X_train_rfe).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     80.20
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           2.83e-56
# Time:                        15:36:22   Log-Likelihood:                 22.962
# No. Observations:                 129   AIC:                             4.075
# Df Residuals:                     104   BIC:                             75.57
# Df Model:                          24
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0262      0.021     -1.236      0.219      -0.068       0.016
# wheelbase                  0.1518      0.058      2.629      0.010       0.037       0.266
# carlength                 -0.1385      0.071     -1.946      0.054      -0.280       0.003
# carwidth                   0.1645      0.064      2.575      0.011       0.038       0.291
# curbweight                 0.2194      0.073      3.011      0.003       0.075       0.364
# horsepower                 0.2246      0.060      3.761      0.000       0.106       0.343
# Symboling_3                0.0905      0.034      2.639      0.010       0.022       0.158
# FuelType_gas              -0.0975      0.035     -2.770      0.007      -0.167      -0.028
# Carbody_hatchback         -0.1981      0.067     -2.970      0.004      -0.330      -0.066
# Carbody_sedan             -0.1158      0.072     -1.607      0.111      -0.259       0.027
# Carbody_wagon             -0.1019      0.052     -1.949      0.054      -0.206       0.002
# DriveWheel_rwd             0.1648      0.039      4.207      0.000       0.087       0.243
# EngineLocation_front      -0.0948      0.054     -1.748      0.083      -0.202       0.013
# EngineType_dohc           -0.2021      0.046     -4.376      0.000      -0.294      -0.111
# EngineType_l              -0.1069      0.030     -3.568      0.001      -0.166      -0.047
# EngineType_ohcv           -0.1339      0.038     -3.481      0.001      -0.210      -0.058
# CylinderNumber_six         0.1823      0.051      3.578      0.001       0.081       0.283
# FuelSystem_2bbl            0.0780      0.042      1.839      0.069      -0.006       0.162
# FuelSystem_mpfi            0.0810      0.043      1.902      0.060      -0.003       0.165
# CompanyName_ALFA-ROMEO     0.0717      0.027      2.643      0.010       0.018       0.126
# CompanyName_AUDI           0.0915      0.022      4.103      0.000       0.047       0.136
# CompanyName_BMW            0.1503      0.030      5.005      0.000       0.091       0.210
# CompanyName_BUICK          0.1050      0.027      3.896      0.000       0.052       0.158
# CompanyName_PORSCHE        0.1081      0.038      2.845      0.005       0.033       0.183
# CompanyName_SAAB           0.0705      0.027      2.570      0.012       0.016       0.125
# ==============================================================================
# Omnibus:                        3.081   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.214   Jarque-Bera (JB):                2.688
# Skew:                           0.348   Prob(JB):                        0.261
# Kurtosis:                       3.124   Cond. No.                         14.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
master_new.drop(['Carbody_sedan'],axis=1,inplace=True)
X_train_rfe.drop(['Carbody_sedan'],axis=1,inplace=True)
X_test_rfe.drop(['Carbody_sedan'],axis=1,inplace=True)

# %%
# X_train_rfe=sm.add_constant(X_train_rfe)
lm3= sm.OLS(Y_train,X_train_rfe).fit()
print(lm3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     82.33
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           1.09e-56
# Time:                        15:36:22   Log-Likelihood:                 21.380
# No. Observations:                 129   AIC:                             5.240
# Df Residuals:                     105   BIC:                             73.88
# Df Model:                          23
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0307      0.021     -1.449      0.150      -0.073       0.011
# wheelbase                  0.1526      0.058      2.623      0.010       0.037       0.268
# carlength                 -0.1511      0.071     -2.120      0.036      -0.292      -0.010
# carwidth                   0.1636      0.064      2.543      0.012       0.036       0.291
# curbweight                 0.2325      0.073      3.187      0.002       0.088       0.377
# horsepower                 0.2135      0.060      3.572      0.001       0.095       0.332
# Symboling_3                0.1068      0.033      3.239      0.002       0.041       0.172
# FuelType_gas              -0.0986      0.035     -2.780      0.006      -0.169      -0.028
# Carbody_hatchback         -0.0999      0.027     -3.710      0.000      -0.153      -0.046
# Carbody_wagon             -0.0276      0.025     -1.123      0.264      -0.076       0.021
# DriveWheel_rwd             0.1622      0.039      4.112      0.000       0.084       0.240
# EngineLocation_front      -0.1258      0.051     -2.462      0.015      -0.227      -0.025
# EngineType_dohc           -0.1936      0.046     -4.189      0.000      -0.285      -0.102
# EngineType_l              -0.1068      0.030     -3.538      0.001      -0.167      -0.047
# EngineType_ohcv           -0.1335      0.039     -3.445      0.001      -0.210      -0.057
# CylinderNumber_six         0.1764      0.051      3.446      0.001       0.075       0.278
# FuelSystem_2bbl            0.0838      0.043      1.968      0.052      -0.001       0.168
# FuelSystem_mpfi            0.0901      0.043      2.119      0.036       0.006       0.174
# CompanyName_ALFA-ROMEO     0.0826      0.026      3.120      0.002       0.030       0.135
# CompanyName_AUDI           0.0910      0.022      4.049      0.000       0.046       0.135
# CompanyName_BMW            0.1520      0.030      5.028      0.000       0.092       0.212
# CompanyName_BUICK          0.1152      0.026      4.364      0.000       0.063       0.168
# CompanyName_PORSCHE        0.1039      0.038      2.720      0.008       0.028       0.180
# CompanyName_SAAB           0.0685      0.028      2.481      0.015       0.014       0.123
# ==============================================================================
# Omnibus:                        2.552   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.279   Jarque-Bera (JB):                2.249
# Skew:                           0.322   Prob(JB):                        0.325
# Kurtosis:                       3.060   Cond. No.                         12.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var    Vif
# 3               curbweight  15.20
# 1                carlength  13.27
# 2                 carwidth  10.34
# 0                wheelbase   9.19
# 4               horsepower   8.65
# 10    EngineLocation_front   6.12
# 14      CylinderNumber_six   5.26
# 21     CompanyName_PORSCHE   4.86
# 16         FuelSystem_mpfi   4.34
# 15         FuelSystem_2bbl   3.85
# 13         EngineType_ohcv   3.44
# 6             FuelType_gas   3.18
# 9           DriveWheel_rwd   2.91
# 12            EngineType_l   2.37
# 19         CompanyName_BMW   2.28
# 11         EngineType_dohc   2.27
# 5              Symboling_3   2.24
# 20       CompanyName_BUICK   1.95
# 7        Carbody_hatchback   1.79
# 22        CompanyName_SAAB   1.68
# 8            Carbody_wagon   1.60
# 17  CompanyName_ALFA-ROMEO   1.52
# 18        CompanyName_AUDI   1.46

# %%
master_new.drop(['Carbody_wagon'],axis=1,inplace=True)
X_train_rfe.drop(['Carbody_wagon'],axis=1,inplace=True)
X_test_rfe.drop(['Carbody_wagon'],axis=1,inplace=True)

# %%
# X_train_rfe=sm.add_constant(X_train_rfe)
lm4= sm.OLS(Y_train,X_train_rfe).fit()
print(lm4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     85.81
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           2.15e-57
# Time:                        15:36:23   Log-Likelihood:                 20.609
# No. Observations:                 129   AIC:                             4.782
# Df Residuals:                     106   BIC:                             70.56
# Df Model:                          22
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0300      0.021     -1.418      0.159      -0.072       0.012
# wheelbase                  0.1470      0.058      2.533      0.013       0.032       0.262
# carlength                 -0.1658      0.070     -2.363      0.020      -0.305      -0.027
# carwidth                   0.1887      0.060      3.124      0.002       0.069       0.309
# curbweight                 0.2067      0.069      2.981      0.004       0.069       0.344
# horsepower                 0.2247      0.059      3.809      0.000       0.108       0.342
# Symboling_3                0.1037      0.033      3.152      0.002       0.038       0.169
# FuelType_gas              -0.1038      0.035     -2.948      0.004      -0.174      -0.034
# Carbody_hatchback         -0.0964      0.027     -3.600      0.000      -0.149      -0.043
# DriveWheel_rwd             0.1697      0.039      4.361      0.000       0.093       0.247
# EngineLocation_front      -0.1279      0.051     -2.501      0.014      -0.229      -0.027
# EngineType_dohc           -0.1908      0.046     -4.128      0.000      -0.282      -0.099
# EngineType_l              -0.1061      0.030     -3.511      0.001      -0.166      -0.046
# EngineType_ohcv           -0.1358      0.039     -3.506      0.001      -0.213      -0.059
# CylinderNumber_six         0.1799      0.051      3.515      0.001       0.078       0.281
# FuelSystem_2bbl            0.0817      0.043      1.918      0.058      -0.003       0.166
# FuelSystem_mpfi            0.0904      0.043      2.125      0.036       0.006       0.175
# CompanyName_ALFA-ROMEO     0.0826      0.027      3.115      0.002       0.030       0.135
# CompanyName_AUDI           0.0923      0.022      4.111      0.000       0.048       0.137
# CompanyName_BMW            0.1559      0.030      5.185      0.000       0.096       0.216
# CompanyName_BUICK          0.1128      0.026      4.284      0.000       0.061       0.165
# CompanyName_PORSCHE        0.0979      0.038      2.586      0.011       0.023       0.173
# CompanyName_SAAB           0.0749      0.027      2.774      0.007       0.021       0.129
# ==============================================================================
# Omnibus:                        3.314   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.191   Jarque-Bera (JB):                2.960
# Skew:                           0.368   Prob(JB):                        0.228
# Kurtosis:                       3.095   Cond. No.                         12.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var    Vif
# 3               curbweight  13.56
# 1                carlength  12.97
# 2                 carwidth   9.41
# 0                wheelbase   9.10
# 4               horsepower   8.20
# 9     EngineLocation_front   6.12
# 13      CylinderNumber_six   5.24
# 20     CompanyName_PORSCHE   4.79
# 15         FuelSystem_mpfi   4.33
# 14         FuelSystem_2bbl   3.85
# 12         EngineType_ohcv   3.43
# 6             FuelType_gas   3.05
# 8           DriveWheel_rwd   2.81
# 11            EngineType_l   2.35
# 10         EngineType_dohc   2.26
# 18         CompanyName_BMW   2.25
# 5              Symboling_3   2.24
# 19       CompanyName_BUICK   1.94
# 7        Carbody_hatchback   1.78
# 21        CompanyName_SAAB   1.61
# 16  CompanyName_ALFA-ROMEO   1.52
# 17        CompanyName_AUDI   1.46

# %%
master_new.drop(['FuelSystem_2bbl'],axis=1,inplace=True)
X_train_rfe.drop(['FuelSystem_2bbl'],axis=1,inplace=True)
X_test_rfe.drop(['FuelSystem_2bbl'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm5= sm.OLS(Y_train,X_train_rfe).fit()
print(lm5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     87.53
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           1.35e-57
# Time:                        15:36:23   Log-Likelihood:                 18.409
# No. Observations:                 129   AIC:                             7.182
# Df Residuals:                     107   BIC:                             70.10
# Df Model:                          21
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0289      0.021     -1.350      0.180      -0.071       0.014
# wheelbase                  0.1430      0.059      2.436      0.017       0.027       0.259
# carlength                 -0.1542      0.071     -2.180      0.031      -0.295      -0.014
# carwidth                   0.1831      0.061      2.997      0.003       0.062       0.304
# curbweight                 0.1989      0.070      2.838      0.005       0.060       0.338
# horsepower                 0.1895      0.057      3.338      0.001       0.077       0.302
# Symboling_3                0.0906      0.033      2.781      0.006       0.026       0.155
# FuelType_gas              -0.0630      0.028     -2.218      0.029      -0.119      -0.007
# Carbody_hatchback         -0.0956      0.027     -3.527      0.001      -0.149      -0.042
# DriveWheel_rwd             0.1743      0.039      4.432      0.000       0.096       0.252
# EngineLocation_front      -0.1294      0.052     -2.500      0.014      -0.232      -0.027
# EngineType_dohc           -0.1830      0.047     -3.926      0.000      -0.275      -0.091
# EngineType_l              -0.1037      0.031     -3.394      0.001      -0.164      -0.043
# EngineType_ohcv           -0.1297      0.039     -3.319      0.001      -0.207      -0.052
# CylinderNumber_six         0.1933      0.051      3.768      0.000       0.092       0.295
# FuelSystem_mpfi            0.0356      0.032      1.116      0.267      -0.028       0.099
# CompanyName_ALFA-ROMEO     0.0806      0.027      3.004      0.003       0.027       0.134
# CompanyName_AUDI           0.0960      0.023      4.237      0.000       0.051       0.141
# CompanyName_BMW            0.1533      0.030      5.039      0.000       0.093       0.214
# CompanyName_BUICK          0.1218      0.026      4.640      0.000       0.070       0.174
# CompanyName_PORSCHE        0.1100      0.038      2.910      0.004       0.035       0.185
# CompanyName_SAAB           0.0770      0.027      2.816      0.006       0.023       0.131
# ==============================================================================
# Omnibus:                        3.422   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.181   Jarque-Bera (JB):                3.153
# Skew:                           0.383   Prob(JB):                        0.207
# Kurtosis:                       3.035   Cond. No.                         12.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var    Vif
# 3               curbweight  13.47
# 1                carlength  12.67
# 2                 carwidth   9.39
# 0                wheelbase   9.08
# 4               horsepower   7.63
# 9     EngineLocation_front   6.12
# 13      CylinderNumber_six   5.12
# 19     CompanyName_PORSCHE   4.69
# 12         EngineType_ohcv   3.42
# 8           DriveWheel_rwd   2.81
# 14         FuelSystem_mpfi   2.64
# 11            EngineType_l   2.35
# 10         EngineType_dohc   2.25
# 17         CompanyName_BMW   2.25
# 6             FuelType_gas   2.17
# 5              Symboling_3   2.14
# 18       CompanyName_BUICK   1.90
# 7        Carbody_hatchback   1.78
# 20        CompanyName_SAAB   1.61
# 15  CompanyName_ALFA-ROMEO   1.52
# 16        CompanyName_AUDI   1.46

# %%
master_new.drop(['FuelSystem_mpfi'],axis=1,inplace=True)
X_train_rfe.drop(['FuelSystem_mpfi'],axis=1,inplace=True)
X_test_rfe.drop(['FuelSystem_mpfi'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm6= sm.OLS(Y_train,X_train_rfe).fit()
print(lm6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     91.63
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           2.57e-58
# Time:                        15:36:23   Log-Likelihood:                 17.663
# No. Observations:                 129   AIC:                             6.675
# Df Residuals:                     108   BIC:                             66.73
# Df Model:                          20
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0275      0.021     -1.284      0.202      -0.070       0.015
# wheelbase                  0.1477      0.059      2.519      0.013       0.031       0.264
# carlength                 -0.1539      0.071     -2.173      0.032      -0.294      -0.014
# carwidth                   0.1923      0.061      3.174      0.002       0.072       0.312
# curbweight                 0.1969      0.070      2.807      0.006       0.058       0.336
# horsepower                 0.1994      0.056      3.554      0.001       0.088       0.311
# Symboling_3                0.0889      0.033      2.727      0.007       0.024       0.153
# FuelType_gas              -0.0528      0.027     -1.962      0.052      -0.106       0.001
# Carbody_hatchback         -0.1009      0.027     -3.775      0.000      -0.154      -0.048
# DriveWheel_rwd             0.1797      0.039      4.600      0.000       0.102       0.257
# EngineLocation_front      -0.1316      0.052     -2.541      0.012      -0.234      -0.029
# EngineType_dohc           -0.1756      0.046     -3.802      0.000      -0.267      -0.084
# EngineType_l              -0.1057      0.031     -3.460      0.001      -0.166      -0.045
# EngineType_ohcv           -0.1218      0.038     -3.165      0.002      -0.198      -0.046
# CylinderNumber_six         0.1852      0.051      3.642      0.000       0.084       0.286
# CompanyName_ALFA-ROMEO     0.0823      0.027      3.070      0.003       0.029       0.135
# CompanyName_AUDI           0.1000      0.022      4.462      0.000       0.056       0.144
# CompanyName_BMW            0.1594      0.030      5.324      0.000       0.100       0.219
# CompanyName_BUICK          0.1161      0.026      4.504      0.000       0.065       0.167
# CompanyName_PORSCHE        0.1130      0.038      2.993      0.003       0.038       0.188
# CompanyName_SAAB           0.0833      0.027      3.113      0.002       0.030       0.136
# ==============================================================================
# Omnibus:                        2.899   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.235   Jarque-Bera (JB):                2.682
# Skew:                           0.353   Prob(JB):                        0.262
# Kurtosis:                       2.997   Cond. No.                         11.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var    Vif
# 3               curbweight  13.47
# 1                carlength  12.67
# 2                 carwidth   9.32
# 0                wheelbase   8.98
# 4               horsepower   7.40
# 9     EngineLocation_front   6.11
# 13      CylinderNumber_six   5.02
# 18     CompanyName_PORSCHE   4.66
# 12         EngineType_ohcv   3.33
# 8           DriveWheel_rwd   2.72
# 11            EngineType_l   2.32
# 16         CompanyName_BMW   2.20
# 10         EngineType_dohc   2.20
# 5              Symboling_3   2.12
# 6             FuelType_gas   1.93
# 17       CompanyName_BUICK   1.83
# 7        Carbody_hatchback   1.73
# 19        CompanyName_SAAB   1.56
# 14  CompanyName_ALFA-ROMEO   1.50
# 15        CompanyName_AUDI   1.43

# %%
master_new.drop(['FuelType_gas'],axis=1,inplace=True)
X_train_rfe.drop(['FuelType_gas'],axis=1,inplace=True)
X_test_rfe.drop(['FuelType_gas'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm7= sm.OLS(Y_train,X_train_rfe).fit()
print(lm7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     93.80
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           1.70e-58
# Time:                        15:36:24   Log-Likelihood:                 15.404
# No. Observations:                 129   AIC:                             9.191
# Df Residuals:                     109   BIC:                             66.39
# Df Model:                          19
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0291      0.022     -1.344      0.182      -0.072       0.014
# wheelbase                  0.1517      0.059      2.555      0.012       0.034       0.269
# carlength                 -0.1731      0.071     -2.436      0.016      -0.314      -0.032
# carwidth                   0.2098      0.061      3.455      0.001       0.089       0.330
# curbweight                 0.2436      0.067      3.646      0.000       0.111       0.376
# horsepower                 0.1451      0.049      2.934      0.004       0.047       0.243
# Symboling_3                0.0956      0.033      2.912      0.004       0.031       0.161
# Carbody_hatchback         -0.1048      0.027     -3.883      0.000      -0.158      -0.051
# DriveWheel_rwd             0.1834      0.040      4.639      0.000       0.105       0.262
# EngineLocation_front      -0.1433      0.052     -2.750      0.007      -0.247      -0.040
# EngineType_dohc           -0.1833      0.047     -3.932      0.000      -0.276      -0.091
# EngineType_l              -0.1140      0.031     -3.720      0.000      -0.175      -0.053
# EngineType_ohcv           -0.1293      0.039     -3.332      0.001      -0.206      -0.052
# CylinderNumber_six         0.1988      0.051      3.895      0.000       0.098       0.300
# CompanyName_ALFA-ROMEO     0.0860      0.027      3.177      0.002       0.032       0.140
# CompanyName_AUDI           0.0980      0.023      4.324      0.000       0.053       0.143
# CompanyName_BMW            0.1555      0.030      5.137      0.000       0.095       0.215
# CompanyName_BUICK          0.1242      0.026      4.821      0.000       0.073       0.175
# CompanyName_PORSCHE        0.1098      0.038      2.874      0.005       0.034       0.186
# CompanyName_SAAB           0.0819      0.027      3.020      0.003       0.028       0.136
# ==============================================================================
# Omnibus:                        3.661   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.160   Jarque-Bera (JB):                3.221
# Skew:                           0.378   Prob(JB):                        0.200
# Kurtosis:                       3.165   Cond. No.                         11.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var    Vif
# 1                carlength  12.12
# 3               curbweight  11.88
# 2                 carwidth   9.00
# 0                wheelbase   8.97
# 8     EngineLocation_front   5.97
# 4               horsepower   5.86
# 12      CylinderNumber_six   5.01
# 17     CompanyName_PORSCHE   4.65
# 11         EngineType_ohcv   3.32
# 7           DriveWheel_rwd   2.72
# 10            EngineType_l   2.32
# 15         CompanyName_BMW   2.20
# 9          EngineType_dohc   2.18
# 5              Symboling_3   2.12
# 16       CompanyName_BUICK   1.78
# 6        Carbody_hatchback   1.72
# 18        CompanyName_SAAB   1.55
# 13  CompanyName_ALFA-ROMEO   1.50
# 14        CompanyName_AUDI   1.41

# %%
master_new.drop(['carlength'],axis=1,inplace=True)
X_train_rfe.drop(['carlength'],axis=1,inplace=True)
X_test_rfe.drop(['carlength'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm8= sm.OLS(Y_train,X_train_rfe).fit()
print(lm8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     94.45
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           3.00e-58
# Time:                        15:36:24   Log-Likelihood:                 11.986
# No. Observations:                 129   AIC:                             14.03
# Df Residuals:                     110   BIC:                             68.36
# Df Model:                          18
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0294      0.022     -1.326      0.188      -0.073       0.015
# wheelbase                  0.0981      0.056      1.741      0.085      -0.014       0.210
# carwidth                   0.1317      0.053      2.499      0.014       0.027       0.236
# curbweight                 0.1650      0.060      2.759      0.007       0.047       0.284
# horsepower                 0.1515      0.050      3.002      0.003       0.051       0.252
# Symboling_3                0.1029      0.033      3.081      0.003       0.037       0.169
# Carbody_hatchback         -0.0850      0.026     -3.232      0.002      -0.137      -0.033
# DriveWheel_rwd             0.1988      0.040      4.984      0.000       0.120       0.278
# EngineLocation_front      -0.1112      0.052     -2.158      0.033      -0.213      -0.009
# EngineType_dohc           -0.2033      0.047     -4.335      0.000      -0.296      -0.110
# EngineType_l              -0.0967      0.030     -3.174      0.002      -0.157      -0.036
# EngineType_ohcv           -0.1332      0.040     -3.362      0.001      -0.212      -0.055
# CylinderNumber_six         0.2238      0.051      4.379      0.000       0.122       0.325
# CompanyName_ALFA-ROMEO     0.0801      0.028      2.905      0.004       0.025       0.135
# CompanyName_AUDI           0.1085      0.023      4.772      0.000       0.063       0.154
# CompanyName_BMW            0.1358      0.030      4.555      0.000       0.077       0.195
# CompanyName_BUICK          0.1546      0.023      6.714      0.000       0.109       0.200
# CompanyName_PORSCHE        0.1283      0.038      3.353      0.001       0.052       0.204
# CompanyName_SAAB           0.0604      0.026      2.306      0.023       0.009       0.112
# ==============================================================================
# Omnibus:                        5.511   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.064   Jarque-Bera (JB):                5.066
# Skew:                           0.397   Prob(JB):                       0.0794
# Kurtosis:                       3.558   Cond. No.                         8.20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var   Vif
# 2               curbweight  9.27
# 0                wheelbase  7.93
# 1                 carwidth  7.17
# 3               horsepower  5.74
# 7     EngineLocation_front  5.69
# 11      CylinderNumber_six  4.92
# 16     CompanyName_PORSCHE  4.50
# 10         EngineType_ohcv  3.32
# 6           DriveWheel_rwd  2.72
# 9             EngineType_l  2.18
# 4              Symboling_3  2.12
# 8          EngineType_dohc  2.11
# 14         CompanyName_BMW  2.11
# 12  CompanyName_ALFA-ROMEO  1.50
# 5        Carbody_hatchback  1.50
# 15       CompanyName_BUICK  1.47
# 13        CompanyName_AUDI  1.39
# 17        CompanyName_SAAB  1.35

# %%
master_new.drop(['wheelbase'],axis=1,inplace=True)
X_train_rfe.drop(['wheelbase'],axis=1,inplace=True)
X_test_rfe.drop(['wheelbase'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm9= sm.OLS(Y_train,X_train_rfe).fit()
print(lm9.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     98.03
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           1.31e-58
# Time:                        15:36:24   Log-Likelihood:                 10.233
# No. Observations:                 129   AIC:                             15.53
# Df Residuals:                     111   BIC:                             67.01
# Df Model:                          17
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0282      0.022     -1.262      0.210      -0.072       0.016
# carwidth                   0.1753      0.047      3.743      0.000       0.082       0.268
# curbweight                 0.2004      0.057      3.530      0.001       0.088       0.313
# horsepower                 0.1339      0.050      2.684      0.008       0.035       0.233
# Symboling_3                0.0810      0.031      2.594      0.011       0.019       0.143
# Carbody_hatchback         -0.0941      0.026     -3.614      0.000      -0.146      -0.042
# DriveWheel_rwd             0.2160      0.039      5.540      0.000       0.139       0.293
# EngineLocation_front      -0.1104      0.052     -2.124      0.036      -0.213      -0.007
# EngineType_dohc           -0.1997      0.047     -4.223      0.000      -0.293      -0.106
# EngineType_l              -0.0809      0.029     -2.757      0.007      -0.139      -0.023
# EngineType_ohcv           -0.1437      0.040     -3.638      0.000      -0.222      -0.065
# CylinderNumber_six         0.2277      0.052      4.420      0.000       0.126       0.330
# CompanyName_ALFA-ROMEO     0.0687      0.027      2.541      0.012       0.015       0.122
# CompanyName_AUDI           0.1069      0.023      4.663      0.000       0.061       0.152
# CompanyName_BMW            0.1389      0.030      4.625      0.000       0.079       0.198
# CompanyName_BUICK          0.1504      0.023      6.507      0.000       0.105       0.196
# CompanyName_PORSCHE        0.1144      0.038      3.030      0.003       0.040       0.189
# CompanyName_SAAB           0.0613      0.026      2.317      0.022       0.009       0.114
# ==============================================================================
# Omnibus:                        8.272   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                8.553
# Skew:                           0.480   Prob(JB):                       0.0139
# Kurtosis:                       3.818   Cond. No.                         7.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var   Vif
# 1               curbweight  8.35
# 6     EngineLocation_front  5.69
# 2               horsepower  5.50
# 0                 carwidth  5.04
# 10      CylinderNumber_six  4.87
# 15     CompanyName_PORSCHE  4.31
# 9          EngineType_ohcv  3.15
# 5           DriveWheel_rwd  2.64
# 7          EngineType_dohc  2.11
# 13         CompanyName_BMW  2.10
# 8             EngineType_l  2.00
# 3              Symboling_3  1.82
# 4        Carbody_hatchback  1.46
# 14       CompanyName_BUICK  1.45
# 11  CompanyName_ALFA-ROMEO  1.41
# 12        CompanyName_AUDI  1.37
# 16        CompanyName_SAAB  1.35

# %%
master_new.drop(['EngineLocation_front'],axis=1,inplace=True)
X_train_rfe.drop(['EngineLocation_front'],axis=1,inplace=True)
X_test_rfe.drop(['EngineLocation_front'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm10= sm.OLS(Y_train,X_train_rfe).fit()
print(lm10.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     100.7
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           1.15e-58
# Time:                        15:36:24   Log-Likelihood:                 7.6642
# No. Observations:                 129   AIC:                             18.67
# Df Residuals:                     112   BIC:                             67.29
# Df Model:                          16
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0339      0.023     -1.503      0.136      -0.079       0.011
# carwidth                   0.1490      0.046      3.248      0.002       0.058       0.240
# curbweight                 0.1881      0.057      3.280      0.001       0.074       0.302
# horsepower                 0.1609      0.049      3.284      0.001       0.064       0.258
# Symboling_3                0.0832      0.032      2.627      0.010       0.020       0.146
# Carbody_hatchback         -0.1057      0.026     -4.089      0.000      -0.157      -0.054
# DriveWheel_rwd             0.2181      0.040      5.511      0.000       0.140       0.297
# EngineType_dohc           -0.2289      0.046     -4.983      0.000      -0.320      -0.138
# EngineType_l              -0.0683      0.029     -2.339      0.021      -0.126      -0.010
# EngineType_ohcv           -0.1755      0.037     -4.723      0.000      -0.249      -0.102
# CylinderNumber_six         0.2737      0.047      5.766      0.000       0.180       0.368
# CompanyName_ALFA-ROMEO     0.0734      0.027      2.685      0.008       0.019       0.128
# CompanyName_AUDI           0.1109      0.023      4.778      0.000       0.065       0.157
# CompanyName_BMW            0.1184      0.029      4.100      0.000       0.061       0.176
# CompanyName_BUICK          0.1599      0.023      6.943      0.000       0.114       0.206
# CompanyName_PORSCHE        0.1617      0.031      5.217      0.000       0.100       0.223
# CompanyName_SAAB           0.0637      0.027      2.376      0.019       0.011       0.117
# ==============================================================================
# Omnibus:                        7.864   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                7.879
# Skew:                           0.480   Prob(JB):                       0.0195
# Kurtosis:                       3.739   Cond. No.                         6.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var   Vif
# 1               curbweight  8.26
# 2               horsepower  5.02
# 0                 carwidth  4.67
# 9       CylinderNumber_six  4.09
# 8          EngineType_ohcv  2.77
# 5           DriveWheel_rwd  2.64
# 14     CompanyName_PORSCHE  2.04
# 6          EngineType_dohc  1.91
# 7             EngineType_l  1.91
# 12         CompanyName_BMW  1.86
# 3              Symboling_3  1.82
# 13       CompanyName_BUICK  1.41
# 10  CompanyName_ALFA-ROMEO  1.40
# 4        Carbody_hatchback  1.40
# 11        CompanyName_AUDI  1.36
# 15        CompanyName_SAAB  1.33

# %%
master_new.drop(['EngineType_l'],axis=1,inplace=True)
X_train_rfe.drop(['EngineType_l'],axis=1,inplace=True)
X_test_rfe.drop(['EngineType_l'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm11= sm.OLS(Y_train,X_train_rfe).fit()
print(lm11.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     103.0
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           1.56e-58
# Time:                        15:36:25   Log-Likelihood:                 4.5885
# No. Observations:                 129   AIC:                             22.82
# Df Residuals:                     113   BIC:                             68.58
# Df Model:                          15
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0355      0.023     -1.547      0.125      -0.081       0.010
# carwidth                   0.1383      0.047      2.972      0.004       0.046       0.230
# curbweight                 0.1409      0.055      2.574      0.011       0.032       0.249
# horsepower                 0.1995      0.047      4.242      0.000       0.106       0.293
# Symboling_3                0.0855      0.032      2.650      0.009       0.022       0.150
# Carbody_hatchback         -0.1026      0.026     -3.897      0.000      -0.155      -0.050
# DriveWheel_rwd             0.1925      0.039      4.964      0.000       0.116       0.269
# EngineType_dohc           -0.2234      0.047     -4.777      0.000      -0.316      -0.131
# EngineType_ohcv           -0.1765      0.038     -4.659      0.000      -0.252      -0.101
# CylinderNumber_six         0.2893      0.048      6.038      0.000       0.194       0.384
# CompanyName_ALFA-ROMEO     0.0741      0.028      2.658      0.009       0.019       0.129
# CompanyName_AUDI           0.1157      0.024      4.909      0.000       0.069       0.162
# CompanyName_BMW            0.1259      0.029      4.303      0.000       0.068       0.184
# CompanyName_BUICK          0.1837      0.021      8.718      0.000       0.142       0.225
# CompanyName_PORSCHE        0.1592      0.032      5.041      0.000       0.097       0.222
# CompanyName_SAAB           0.0688      0.027      2.524      0.013       0.015       0.123
# ==============================================================================
# Omnibus:                       16.661   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.705
# Skew:                           0.640   Prob(JB):                     2.62e-06
# Kurtosis:                       4.773   Cond. No.                         6.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var   Vif
# 1               curbweight  7.10
# 0                 carwidth  4.64
# 2               horsepower  4.26
# 8       CylinderNumber_six  4.02
# 7          EngineType_ohcv  2.77
# 5           DriveWheel_rwd  2.55
# 13     CompanyName_PORSCHE  1.99
# 6          EngineType_dohc  1.91
# 11         CompanyName_BMW  1.86
# 3              Symboling_3  1.82
# 9   CompanyName_ALFA-ROMEO  1.40
# 4        Carbody_hatchback  1.40
# 10        CompanyName_AUDI  1.34
# 14        CompanyName_SAAB  1.33
# 12       CompanyName_BUICK  1.22

# %%
master_new.drop(['curbweight'],axis=1,inplace=True)
X_train_rfe.drop(['curbweight'],axis=1,inplace=True)
X_test_rfe.drop(['curbweight'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm12= sm.OLS(Y_train,X_train_rfe).fit()
print(lm12.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     104.7
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           3.64e-58
# Time:                        15:36:25   Log-Likelihood:                0.91368
# No. Observations:                 129   AIC:                             28.17
# Df Residuals:                     114   BIC:                             71.07
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0309      0.023     -1.318      0.190      -0.077       0.016
# carwidth                   0.2121      0.038      5.652      0.000       0.138       0.286
# horsepower                 0.2463      0.044      5.540      0.000       0.158       0.334
# Symboling_3                0.0839      0.033      2.539      0.012       0.018       0.149
# Carbody_hatchback         -0.1168      0.026     -4.432      0.000      -0.169      -0.065
# DriveWheel_rwd             0.2231      0.038      5.903      0.000       0.148       0.298
# EngineType_dohc           -0.2290      0.048     -4.785      0.000      -0.324      -0.134
# EngineType_ohcv           -0.1796      0.039     -4.632      0.000      -0.256      -0.103
# CylinderNumber_six         0.3016      0.049      6.175      0.000       0.205       0.398
# CompanyName_ALFA-ROMEO     0.0756      0.029      2.647      0.009       0.019       0.132
# CompanyName_AUDI           0.1103      0.024      4.586      0.000       0.063       0.158
# CompanyName_BMW            0.1204      0.030      4.027      0.000       0.061       0.180
# CompanyName_BUICK          0.1912      0.021      8.949      0.000       0.149       0.234
# CompanyName_PORSCHE        0.1419      0.032      4.490      0.000       0.079       0.205
# CompanyName_SAAB           0.0757      0.028      2.725      0.007       0.021       0.131
# ==============================================================================
# Omnibus:                       12.238   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.239
# Skew:                           0.564   Prob(JB):                     0.000491
# Kurtosis:                       4.250   Cond. No.                         5.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var   Vif
# 7       CylinderNumber_six  3.94
# 1               horsepower  3.61
# 6          EngineType_ohcv  2.76
# 0                 carwidth  2.53
# 4           DriveWheel_rwd  2.27
# 5          EngineType_dohc  1.90
# 12     CompanyName_PORSCHE  1.89
# 10         CompanyName_BMW  1.85
# 2              Symboling_3  1.82
# 8   CompanyName_ALFA-ROMEO  1.39
# 9         CompanyName_AUDI  1.32
# 3        Carbody_hatchback  1.32
# 13        CompanyName_SAAB  1.31
# 11       CompanyName_BUICK  1.19

# %%
master_new.drop(['Symboling_3'],axis=1,inplace=True)
X_train_rfe.drop(['Symboling_3'],axis=1,inplace=True)
X_test_rfe.drop(['Symboling_3'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm13= sm.OLS(Y_train,X_train_rfe).fit()
print(lm13.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     107.2
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           7.70e-58
# Time:                        15:36:25   Log-Likelihood:                -2.6338
# No. Observations:                 129   AIC:                             33.27
# Df Residuals:                     115   BIC:                             73.30
# Df Model:                          13
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0255      0.024     -1.065      0.289      -0.073       0.022
# carwidth                   0.2052      0.038      5.357      0.000       0.129       0.281
# horsepower                 0.2943      0.041      7.148      0.000       0.213       0.376
# Carbody_hatchback         -0.0904      0.025     -3.648      0.000      -0.140      -0.041
# DriveWheel_rwd             0.2213      0.039      5.722      0.000       0.145       0.298
# EngineType_dohc           -0.2024      0.048     -4.235      0.000      -0.297      -0.108
# EngineType_ohcv           -0.1748      0.040     -4.411      0.000      -0.253      -0.096
# CylinderNumber_six         0.2790      0.049      5.676      0.000       0.182       0.376
# CompanyName_ALFA-ROMEO     0.0747      0.029      2.555      0.012       0.017       0.133
# CompanyName_AUDI           0.1014      0.024      4.165      0.000       0.053       0.150
# CompanyName_BMW            0.1187      0.031      3.882      0.000       0.058       0.179
# CompanyName_BUICK          0.1875      0.022      8.593      0.000       0.144       0.231
# CompanyName_PORSCHE        0.1609      0.031      5.119      0.000       0.099       0.223
# CompanyName_SAAB           0.0814      0.028      2.872      0.005       0.025       0.138
# ==============================================================================
# Omnibus:                       12.574   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.151
# Skew:                           0.596   Prob(JB):                     0.000513
# Kurtosis:                       4.182   Cond. No.                         5.38
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                        Var   Vif
# 6       CylinderNumber_six  3.93
# 1               horsepower  3.27
# 5          EngineType_ohcv  2.74
# 0                 carwidth  2.53
# 3           DriveWheel_rwd  2.27
# 4          EngineType_dohc  1.89
# 9          CompanyName_BMW  1.84
# 11     CompanyName_PORSCHE  1.81
# 7   CompanyName_ALFA-ROMEO  1.34
# 8         CompanyName_AUDI  1.31
# 12        CompanyName_SAAB  1.29
# 10       CompanyName_BUICK  1.19
# 2        Carbody_hatchback  1.11

# %%
master_new.drop(['CompanyName_ALFA-ROMEO'],axis=1,inplace=True)
X_train_rfe.drop(['CompanyName_ALFA-ROMEO'],axis=1,inplace=True)
X_test_rfe.drop(['CompanyName_ALFA-ROMEO'],axis=1,inplace=True)
# X_train_rfe=sm.add_constant(X_train_rfe)
lm14= sm.OLS(Y_train,X_train_rfe).fit()
print(lm14.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     110.3
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           1.67e-57
# Time:                        15:36:25   Log-Likelihood:                -6.1955
# No. Observations:                 129   AIC:                             38.39
# Df Residuals:                     116   BIC:                             75.57
# Df Model:                          12
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.0190      0.024     -0.779      0.437      -0.067       0.029
# carwidth                0.1822      0.038      4.782      0.000       0.107       0.258
# horsepower              0.2917      0.042      6.926      0.000       0.208       0.375
# Carbody_hatchback      -0.0918      0.025     -3.618      0.000      -0.142      -0.042
# DriveWheel_rwd          0.2456      0.038      6.401      0.000       0.170       0.322
# EngineType_dohc        -0.1481      0.044     -3.380      0.001      -0.235      -0.061
# EngineType_ohcv        -0.1344      0.037     -3.613      0.000      -0.208      -0.061
# CylinderNumber_six      0.2458      0.049      5.066      0.000       0.150       0.342
# CompanyName_AUDI        0.1090      0.025      4.403      0.000       0.060       0.158
# CompanyName_BMW         0.1240      0.031      3.970      0.000       0.062       0.186
# CompanyName_BUICK       0.1909      0.022      8.562      0.000       0.147       0.235
# CompanyName_PORSCHE     0.1661      0.032      5.174      0.000       0.102       0.230
# CompanyName_SAAB        0.0862      0.029      2.977      0.004       0.029       0.144
# ==============================================================================
# Omnibus:                       11.817   Durbin-Watson:                   1.746
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.038
# Skew:                           0.617   Prob(JB):                      0.00148
# Kurtosis:                       3.950   Cond. No.                         4.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new,'price')
# Out:
#                     Var   Vif
# 6    CylinderNumber_six  3.77
# 1            horsepower  3.26
# 5       EngineType_ohcv  2.47
# 0              carwidth  2.46
# 3        DriveWheel_rwd  2.19
# 8       CompanyName_BMW  1.83
# 10  CompanyName_PORSCHE  1.80
# 4       EngineType_dohc  1.65
# 7      CompanyName_AUDI  1.30
# 11     CompanyName_SAAB  1.29
# 9     CompanyName_BUICK  1.19
# 2     Carbody_hatchback  1.10

# %%
master_new.drop(['CompanyName_SAAB'],axis=1,inplace=True)
X_train_rfe.drop(['CompanyName_SAAB'],axis=1,inplace=True)
X_test_rfe.drop(['CompanyName_SAAB'],axis=1,inplace=True)

lm15 = sm.OLS(Y_train, X_train_rfe).fit()
print(lm15.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     112.0
# Date:                Sun, 07 Apr 2019   Prob (F-statistic):           1.07e-56
# Time:                        15:46:27   Log-Likelihood:                -10.946
# No. Observations:                 129   AIC:                             45.89
# Df Residuals:                     117   BIC:                             80.21
# Df Model:                          11
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.0236      0.025     -0.942      0.348      -0.073       0.026
# carwidth                0.2001      0.039      5.145      0.000       0.123       0.277
# horsepower              0.3101      0.043      7.204      0.000       0.225       0.395
# Carbody_hatchback      -0.0908      0.026     -3.467      0.001      -0.143      -0.039
# DriveWheel_rwd          0.2197      0.039      5.690      0.000       0.143       0.296
# EngineType_dohc        -0.1456      0.045     -3.217      0.002      -0.235      -0.056
# EngineType_ohcv        -0.1387      0.038     -3.612      0.000      -0.215      -0.063
# CylinderNumber_six      0.2365      0.050      4.728      0.000       0.137       0.336
# CompanyName_AUDI        0.0974      0.025      3.857      0.000       0.047       0.147
# CompanyName_BMW         0.1286      0.032      3.991      0.000       0.065       0.192
# CompanyName_BUICK       0.1858      0.023      8.091      0.000       0.140       0.231
# CompanyName_PORSCHE     0.1635      0.033      4.933      0.000       0.098       0.229
# ==============================================================================
# Omnibus:                       15.167   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.633
# Skew:                           0.736   Prob(JB):                     0.000148
# Kurtosis:                       4.056   Cond. No.                         4.93
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
statsmodels_vif_cal(master_new , 'price')
# Out:
#                     Var   Vif
# 6    CylinderNumber_six  3.60
# 1            horsepower  3.12
# 5       EngineType_ohcv  2.46
# 0              carwidth  2.36
# 3        DriveWheel_rwd  1.93
# 10  CompanyName_PORSCHE  1.79
# 8       CompanyName_BMW  1.79
# 4       EngineType_dohc  1.52
# 7      CompanyName_AUDI  1.25
# 9     CompanyName_BUICK  1.18
# 2     Carbody_hatchback  1.10

# %%
X_test_15 = sm.add_constant(X_test_rfe,has_constant= 'add')
y_pred_15=lm15.predict(X_test_15)

# %%
from sklearn.metrics import r2_score ,mean_squared_error

# %%
r2_score(Y_test,y_pred_15)
# Out:
# 0.809465980373314

# %%
mean_squared_error(Y_test,y_pred_15)
# Out:
# 0.2725866245787088

# %%
Y_test.shape
# Out:
# (56,)

# %%
y_pred_15.shape
# Out:
# (56,)

# %%
c = [i for i in range(1,57,1)] # generating index 

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
fig = plt.figure(figsize=(15,10))

plt.plot(c, Y_test, color="blue", linewidth=5, linestyle="-")     # Plotting Actual
plt.plot(c, y_pred_15, color="red",  linewidth=5, linestyle="-") # Plotting predicted
fig.suptitle('Actual and Predicted', fontsize=40)                  # Plot heading 
plt.xlabel('Index', fontsize=30)                                   # X-label
plt.ylabel('Car Price', fontsize=30)                               # Y-label
plt.show()
